# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 729

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hosakote
# Processing Record 2 of Set 1 | katsuura
# Processing Record 3 of Set 1 | mizan teferi
# Processing Record 4 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | serik
# Processing Record 7 of Set 1 | araguatins
# City not found. Skipping...
# Processing Record 8 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 9 of Set 1 | cidreira
# Processing Record 10 of Set 1 | san vicente
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | shaoguan
# Processing Record 14 of Set 1 | victoria
# Processing Record 15 of Set 1 | khatanga
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | imeni poliny osipenko
# Processing Record 18 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 1 | urumqi
# Processing Record 20 of Set 1 | ancud
# Processing Record 21 of Set 1 | saskylakh
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | bereznik
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | carbonia
# Processing Record 31 of Set 1 | inta
# Processing Record 32 of Set 1 | penzance
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | kahului
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | vallenar
# Processing Record 37 of Set 1 | general roca
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | narsaq
# Processing Record 40 of Set 1 | ulaangom
# Processing Record 41 of Set 1 | vilyuysk
# Processing Record 42 of Set 1 | mahebourg
# Processing Record 43 of Set 1 | ternate
# Processing Record 44 of Set 1 | fairbanks
# Processing Record 45 of Set 1 | touros
# Processing Record 46 of Set 1 | aklavik
# Processing Record 47 of Set 1 | ninghai
# Processing Record 48 of Set 1 | namatanai
# Processing Record 49 of Set 1 | ixtapa
# Processing Record 50 of Set 1 | faanui
# Processing Record 1 of Set 2 | wellington
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | bambous virieux
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | cabedelo
# Processing Record 6 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 2 | kruisfontein
# Processing Record 8 of Set 2 | san lawrenz
# Processing Record 9 of Set 2 | san cristobal
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | vardo
# Processing Record 12 of Set 2 | brazzaville
# Processing Record 13 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | najran
# Processing Record 16 of Set 2 | dubuque
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | creston
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | bontang
# Processing Record 21 of Set 2 | betanzos
# Processing Record 22 of Set 2 | shimoda
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | mgachi
# Processing Record 25 of Set 2 | provideniya
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | mount gambier
# Processing Record 29 of Set 2 | udachnyy
# Processing Record 30 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 2 | parana
# Processing Record 32 of Set 2 | arraial do cabo
# Processing Record 33 of Set 2 | sechura
# Processing Record 34 of Set 2 | evans
# Processing Record 35 of Set 2 | airai
# Processing Record 36 of Set 2 | vaini
# Processing Record 37 of Set 2 | pevek
# Processing Record 38 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | wakkanai
# Processing Record 41 of Set 2 | sao joao da barra
# Processing Record 42 of Set 2 | nicoya
# Processing Record 43 of Set 2 | portland
# Processing Record 44 of Set 2 | anadyr
# Processing Record 45 of Set 2 | torbay
# Processing Record 46 of Set 2 | homer
# Processing Record 47 of Set 2 | bathsheba
# Processing Record 48 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 49 of Set 2 | tuatapere
# Processing Record 50 of Set 2 | nikolskoye
# Processing Record 1 of Set 3 | korhogo
# Processing Record 2 of Set 3 | puerto ayora
# Processing Record 3 of Set 3 | nioro
# Processing Record 4 of Set 3 | lebu
# Processing Record 5 of Set 3 | zhigansk
# Processing Record 6 of Set 3 | castro
# Processing Record 7 of Set 3 | kulpahar
# Processing Record 8 of Set 3 | manokwari
# Processing Record 9 of Set 3 | hualmay
# Processing Record 10 of Set 3 | hovd
# Processing Record 11 of Set 3 | hermanus
# Processing Record 12 of Set 3 | porto torres
# Processing Record 13 of Set 3 | kuusamo
# Processing Record 14 of Set 3 | xiongzhou
# Processing Record 15 of Set 3 | yellowknife
# Processing Record 16 of Set 3 | albany
# Processing Record 17 of Set 3 | dikson
# Processing Record 18 of Set 3 | aleksandrov gay
# Processing Record 19 of Set 3 | roald
# Processing Record 20 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 21 of Set 3 | shache
# Processing Record 22 of Set 3 | port alfred
# Processing Record 23 of Set 3 | dessalines
# Processing Record 24 of Set 3 | bengkulu
# Processing Record 25 of Set 3 | hilo
# Processing Record 26 of Set 3 | valle de allende
# Processing Record 27 of Set 3 | bardiyah
# Processing Record 28 of Set 3 | tonj
# Processing Record 29 of Set 3 | kalispell
# Processing Record 30 of Set 3 | sitka
# Processing Record 31 of Set 3 | vestmannaeyjar
# Processing Record 32 of Set 3 | la ciotat
# Processing Record 33 of Set 3 | san juan
# Processing Record 34 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 35 of Set 3 | new norfolk
# Processing Record 36 of Set 3 | bolgatanga
# Processing Record 37 of Set 3 | nata
# Processing Record 38 of Set 3 | shubarkuduk
# Processing Record 39 of Set 3 | los llanos de aridane
# Processing Record 40 of Set 3 | marsh harbour
# Processing Record 41 of Set 3 | nadym
# Processing Record 42 of Set 3 | san miguel
# Processing Record 43 of Set 3 | kifri
# Processing Record 44 of Set 3 | esperance
# Processing Record 45 of Set 3 | east london
# Processing Record 46 of Set 3 | nehe
# Processing Record 47 of Set 3 | holme
# Processing Record 48 of Set 3 | pangnirtung
# Processing Record 49 of Set 3 | luderitz
# Processing Record 50 of Set 3 | kavaratti
# Processing Record 1 of Set 4 | miedzyrzecz
# Processing Record 2 of Set 4 | aanekoski
# Processing Record 3 of Set 4 | klaksvik
# Processing Record 4 of Set 4 | cape town
# Processing Record 5 of Set 4 | gazanjyk
# Processing Record 6 of Set 4 | launceston
# Processing Record 7 of Set 4 | sucua
# Processing Record 8 of Set 4 | noumea
# Processing Record 9 of Set 4 | georgetown
# Processing Record 10 of Set 4 | cabo san lucas
# Processing Record 11 of Set 4 | balestrand
# Processing Record 12 of Set 4 | provost
# Processing Record 13 of Set 4 | tucuman
# Processing Record 14 of Set 4 | raudeberg
# Processing Record 15 of Set 4 | collie
# Processing Record 16 of Set 4 | hobyo
# Processing Record 17 of Set 4 | novosergiyevka
# Processing Record 18 of Set 4 | chapais
# Processing Record 19 of Set 4 | lorengau
# Processing Record 20 of Set 4 | coracao de jesus
# Processing Record 21 of Set 4 | sehithwa
# Processing Record 22 of Set 4 | elizabeth city
# Processing Record 23 of Set 4 | talnakh
# Processing Record 24 of Set 4 | carnarvon
# Processing Record 25 of Set 4 | pisco
# Processing Record 26 of Set 4 | rawson
# Processing Record 27 of Set 4 | souillac
# Processing Record 28 of Set 4 | kodiak
# Processing Record 29 of Set 4 | channel-port aux basques
# Processing Record 30 of Set 4 | saldanha
# Processing Record 31 of Set 4 | upernavik
# Processing Record 32 of Set 4 | buala
# Processing Record 33 of Set 4 | gat
# Processing Record 34 of Set 4 | isangel
# Processing Record 35 of Set 4 | pacific grove
# Processing Record 36 of Set 4 | bredasdorp
# Processing Record 37 of Set 4 | sept-iles
# Processing Record 38 of Set 4 | waipawa
# Processing Record 39 of Set 4 | malatya
# Processing Record 40 of Set 4 | tongchuan
# Processing Record 41 of Set 4 | kawalu
# Processing Record 42 of Set 4 | honiara
# Processing Record 43 of Set 4 | oktyabrskoye
# Processing Record 44 of Set 4 | formby
# Processing Record 45 of Set 4 | iqaluit
# Processing Record 46 of Set 4 | ostrovnoy
# Processing Record 47 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 4 | noshiro
# Processing Record 49 of Set 4 | rozvadiv
# Processing Record 50 of Set 4 | baijiantan
# Processing Record 1 of Set 5 | matay
# Processing Record 2 of Set 5 | kuytun
# Processing Record 3 of Set 5 | hailar
# Processing Record 4 of Set 5 | nawabshah
# Processing Record 5 of Set 5 | coetupo
# City not found. Skipping...
# Processing Record 6 of Set 5 | tuktoyaktuk
# Processing Record 7 of Set 5 | guerrero negro
# Processing Record 8 of Set 5 | balimo
# City not found. Skipping...
# Processing Record 9 of Set 5 | ozu
# Processing Record 10 of Set 5 | chokurdakh
# Processing Record 11 of Set 5 | caravelas
# Processing Record 12 of Set 5 | alofi
# Processing Record 13 of Set 5 | rio gallegos
# Processing Record 14 of Set 5 | warwick
# Processing Record 15 of Set 5 | gushi
# Processing Record 16 of Set 5 | safakulevo
# Processing Record 17 of Set 5 | tasiilaq
# Processing Record 18 of Set 5 | taoudenni
# Processing Record 19 of Set 5 | paratinga
# Processing Record 20 of Set 5 | hwange
# Processing Record 21 of Set 5 | vanavara
# Processing Record 22 of Set 5 | qasigiannguit
# Processing Record 23 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 5 | evensk
# Processing Record 25 of Set 5 | chuy
# Processing Record 26 of Set 5 | palmer
# Processing Record 27 of Set 5 | broken hill
# Processing Record 28 of Set 5 | sorland
# Processing Record 29 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 30 of Set 5 | kahta
# Processing Record 31 of Set 5 | monchegorsk
# Processing Record 32 of Set 5 | nanortalik
# Processing Record 33 of Set 5 | shingu
# Processing Record 34 of Set 5 | namibe
# Processing Record 35 of Set 5 | kamenka
# Processing Record 36 of Set 5 | kaitangata
# Processing Record 37 of Set 5 | tevriz
# Processing Record 38 of Set 5 | troy
# Processing Record 39 of Set 5 | voh
# Processing Record 40 of Set 5 | longyearbyen
# Processing Record 41 of Set 5 | alyangula
# Processing Record 42 of Set 5 | cacoal
# Processing Record 43 of Set 5 | machacamarca
# Processing Record 44 of Set 5 | inirida
# Processing Record 45 of Set 5 | amboasary
# Processing Record 46 of Set 5 | kavieng
# Processing Record 47 of Set 5 | salalah
# Processing Record 48 of Set 5 | ponta do sol
# Processing Record 49 of Set 5 | clyde river
# Processing Record 50 of Set 5 | borjomi
# Processing Record 1 of Set 6 | nobres
# Processing Record 2 of Set 6 | bud
# Processing Record 3 of Set 6 | kaffrine
# Processing Record 4 of Set 6 | shakawe
# Processing Record 5 of Set 6 | bintulu
# Processing Record 6 of Set 6 | batouri
# Processing Record 7 of Set 6 | chulym
# Processing Record 8 of Set 6 | jalu
# Processing Record 9 of Set 6 | ucluelet
# Processing Record 10 of Set 6 | turayf
# Processing Record 11 of Set 6 | puerto colombia
# Processing Record 12 of Set 6 | dalby
# Processing Record 13 of Set 6 | werda
# Processing Record 14 of Set 6 | porto novo
# Processing Record 15 of Set 6 | sahrak
# City not found. Skipping...
# Processing Record 16 of Set 6 | antalaha
# Processing Record 17 of Set 6 | nelson
# Processing Record 18 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 6 | vao
# Processing Record 20 of Set 6 | esna
# Processing Record 21 of Set 6 | eyl
# Processing Record 22 of Set 6 | araouane
# Processing Record 23 of Set 6 | koulikoro
# Processing Record 24 of Set 6 | qui nhon
# Processing Record 25 of Set 6 | atar
# Processing Record 26 of Set 6 | saint-philippe
# Processing Record 27 of Set 6 | pathein
# Processing Record 28 of Set 6 | waddan
# Processing Record 29 of Set 6 | san patricio
# Processing Record 30 of Set 6 | camacha
# Processing Record 31 of Set 6 | sao filipe
# Processing Record 32 of Set 6 | coquimbo
# Processing Record 33 of Set 6 | port hardy
# Processing Record 34 of Set 6 | ziro
# Processing Record 35 of Set 6 | hukuntsi
# Processing Record 36 of Set 6 | sarkand
# Processing Record 37 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 6 | dunedin
# Processing Record 39 of Set 6 | ladario
# Processing Record 40 of Set 6 | soubre
# Processing Record 41 of Set 6 | lompoc
# Processing Record 42 of Set 6 | ruthin
# Processing Record 43 of Set 6 | krasnoselkup
# Processing Record 44 of Set 6 | chiang rai
# Processing Record 45 of Set 6 | cherskiy
# Processing Record 46 of Set 6 | prince rupert
# Processing Record 47 of Set 6 | skelleftea
# Processing Record 48 of Set 6 | chodavaram
# Processing Record 49 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 6 | egvekinot
# Processing Record 1 of Set 7 | sao felix do xingu
# Processing Record 2 of Set 7 | sheridan
# Processing Record 3 of Set 7 | ayr
# Processing Record 4 of Set 7 | gunjur
# Processing Record 5 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 7 | leningradskiy
# Processing Record 7 of Set 7 | grand gaube
# Processing Record 8 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 7 | naryan-mar
# Processing Record 10 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 7 | benghazi
# Processing Record 12 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 7 | husavik
# Processing Record 14 of Set 7 | waitara
# Processing Record 15 of Set 7 | lagoa
# Processing Record 16 of Set 7 | bulungu
# Processing Record 17 of Set 7 | berdigestyakh
# Processing Record 18 of Set 7 | komsomolskiy
# Processing Record 19 of Set 7 | raga
# Processing Record 20 of Set 7 | westport
# Processing Record 21 of Set 7 | severo-kurilsk
# Processing Record 22 of Set 7 | sanandaj
# Processing Record 23 of Set 7 | ambilobe
# Processing Record 24 of Set 7 | keningau
# Processing Record 25 of Set 7 | yasothon
# Processing Record 26 of Set 7 | corinth
# Processing Record 27 of Set 7 | necochea
# Processing Record 28 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 29 of Set 7 | sao miguel do araguaia
# Processing Record 30 of Set 7 | zhanakorgan
# Processing Record 31 of Set 7 | bowen
# Processing Record 32 of Set 7 | beringovskiy
# Processing Record 33 of Set 7 | fortuna
# Processing Record 34 of Set 7 | jieshi
# Processing Record 35 of Set 7 | ponta delgada
# Processing Record 36 of Set 7 | adre
# Processing Record 37 of Set 7 | grindavik
# Processing Record 38 of Set 7 | maple creek
# Processing Record 39 of Set 7 | alexandria
# Processing Record 40 of Set 7 | burnie
# Processing Record 41 of Set 7 | hastings
# Processing Record 42 of Set 7 | snezhnogorsk
# Processing Record 43 of Set 7 | ahipara
# Processing Record 44 of Set 7 | mangrol
# Processing Record 45 of Set 7 | mazatlan
# Processing Record 46 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 7 | codrington
# Processing Record 48 of Set 7 | chunskiy
# Processing Record 49 of Set 7 | olafsvik
# Processing Record 50 of Set 7 | tyret pervaya
# Processing Record 1 of Set 8 | richards bay
# Processing Record 2 of Set 8 | cape coast
# Processing Record 3 of Set 8 | sinjah
# City not found. Skipping...
# Processing Record 4 of Set 8 | rockport
# Processing Record 5 of Set 8 | culebra
# Processing Record 6 of Set 8 | son la
# Processing Record 7 of Set 8 | myitkyina
# Processing Record 8 of Set 8 | faya
# Processing Record 9 of Set 8 | flinders
# Processing Record 10 of Set 8 | labuhan
# Processing Record 11 of Set 8 | camapua
# Processing Record 12 of Set 8 | yagodnoye
# Processing Record 13 of Set 8 | boyolangu
# Processing Record 14 of Set 8 | pucallpa
# Processing Record 15 of Set 8 | micheweni
# Processing Record 16 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 17 of Set 8 | bubaque
# Processing Record 18 of Set 8 | norman wells
# Processing Record 19 of Set 8 | naze
# Processing Record 20 of Set 8 | kirovskiy
# Processing Record 21 of Set 8 | geraldton
# Processing Record 22 of Set 8 | kungurtug
# Processing Record 23 of Set 8 | chippewa falls
# Processing Record 24 of Set 8 | linxia
# Processing Record 25 of Set 8 | suzu
# City not found. Skipping...
# Processing Record 26 of Set 8 | darnah
# Processing Record 27 of Set 8 | muros
# Processing Record 28 of Set 8 | gornopravdinsk
# Processing Record 29 of Set 8 | vila franca do campo
# Processing Record 30 of Set 8 | abnub
# Processing Record 31 of Set 8 | cochrane
# Processing Record 32 of Set 8 | hellvik
# Processing Record 33 of Set 8 | bogandinskiy
# Processing Record 34 of Set 8 | rizhao
# Processing Record 35 of Set 8 | weligama
# Processing Record 36 of Set 8 | kantang
# Processing Record 37 of Set 8 | kwekwe
# Processing Record 38 of Set 8 | sungaipenuh
# Processing Record 39 of Set 8 | nantucket
# Processing Record 40 of Set 8 | mubi
# Processing Record 41 of Set 8 | canto do buriti
# Processing Record 42 of Set 8 | batagay-alyta
# Processing Record 43 of Set 8 | terrace
# Processing Record 44 of Set 8 | porto belo
# Processing Record 45 of Set 8 | meulaboh
# Processing Record 46 of Set 8 | cap malheureux
# Processing Record 47 of Set 8 | kondopoga
# Processing Record 48 of Set 8 | vilhena
# Processing Record 49 of Set 8 | dingle
# Processing Record 50 of Set 8 | biak
# Processing Record 1 of Set 9 | awjilah
# Processing Record 2 of Set 9 | senmonorom
# City not found. Skipping...
# Processing Record 3 of Set 9 | sal rei
# Processing Record 4 of Set 9 | oussouye
# Processing Record 5 of Set 9 | sakaraha
# Processing Record 6 of Set 9 | swan hill
# Processing Record 7 of Set 9 | sovetsk
# Processing Record 8 of Set 9 | bilibino
# Processing Record 9 of Set 9 | la ronge
# Processing Record 10 of Set 9 | taloda
# Processing Record 11 of Set 9 | kincardine
# Processing Record 12 of Set 9 | kuandian
# Processing Record 13 of Set 9 | xiangdong
# City not found. Skipping...
# Processing Record 14 of Set 9 | santa rosa
# Processing Record 15 of Set 9 | constitucion
# Processing Record 16 of Set 9 | samarai
# Processing Record 17 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 9 | posse
# Processing Record 20 of Set 9 | asyut
# Processing Record 21 of Set 9 | custoias
# Processing Record 22 of Set 9 | viedma
# Processing Record 23 of Set 9 | torrington
# Processing Record 24 of Set 9 | quballat
# Processing Record 25 of Set 9 | lekoni
# Processing Record 26 of Set 9 | zabaykalsk
# Processing Record 27 of Set 9 | vrangel
# Processing Record 28 of Set 9 | kiunga
# Processing Record 29 of Set 9 | popondetta
# Processing Record 30 of Set 9 | marawi
# Processing Record 31 of Set 9 | dhangadhi
# Processing Record 32 of Set 9 | lucapa
# Processing Record 33 of Set 9 | grafton
# Processing Record 34 of Set 9 | conde
# Processing Record 35 of Set 9 | suntar
# Processing Record 36 of Set 9 | high level
# Processing Record 37 of Set 9 | sola
# Processing Record 38 of Set 9 | sosnovo-ozerskoye
# Processing Record 39 of Set 9 | north platte
# Processing Record 40 of Set 9 | stillwater
# Processing Record 41 of Set 9 | shenjiamen
# Processing Record 42 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 9 | grootfontein
# Processing Record 44 of Set 9 | khambhat
# Processing Record 45 of Set 9 | karasjok
# Processing Record 46 of Set 9 | nizwa
# Processing Record 47 of Set 9 | berlevag
# Processing Record 48 of Set 9 | riyadh
# Processing Record 49 of Set 9 | alice springs
# Processing Record 50 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 10 | port blair
# Processing Record 2 of Set 10 | mobaye
# Processing Record 3 of Set 10 | bambanglipuro
# Processing Record 4 of Set 10 | arman
# Processing Record 5 of Set 10 | macomb
# Processing Record 6 of Set 10 | manga
# Processing Record 7 of Set 10 | manta
# Processing Record 8 of Set 10 | ciro marina
# Processing Record 9 of Set 10 | pamanukan
# Processing Record 10 of Set 10 | kiama
# Processing Record 11 of Set 10 | itaqui
# Processing Record 12 of Set 10 | henties bay
# Processing Record 13 of Set 10 | touho
# Processing Record 14 of Set 10 | jacareacanga
# Processing Record 15 of Set 10 | acapulco
# Processing Record 16 of Set 10 | presidencia roque saenz pena
# Processing Record 17 of Set 10 | hambantota
# Processing Record 18 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 10 | jeremie
# Processing Record 20 of Set 10 | nome
# Processing Record 21 of Set 10 | balykshi
# Processing Record 22 of Set 10 | northam
# Processing Record 23 of Set 10 | dan khun thot
# Processing Record 24 of Set 10 | luebo
# Processing Record 25 of Set 10 | saint-augustin
# Processing Record 26 of Set 10 | tura
# Processing Record 27 of Set 10 | kribi
# Processing Record 28 of Set 10 | amparai
# City not found. Skipping...
# Processing Record 29 of Set 10 | kintampo
# Processing Record 30 of Set 10 | sao jose do campestre
# Processing Record 31 of Set 10 | wattegama
# Processing Record 32 of Set 10 | urucara
# Processing Record 33 of Set 10 | tyup
# Processing Record 34 of Set 10 | la palma
# Processing Record 35 of Set 10 | dawlatabad
# Processing Record 36 of Set 10 | lingao
# Processing Record 37 of Set 10 | korgen
# Processing Record 38 of Set 10 | vila velha
# Processing Record 39 of Set 10 | teya
# Processing Record 40 of Set 10 | te anau
# Processing Record 41 of Set 10 | solnechnyy
# Processing Record 42 of Set 10 | kupang
# Processing Record 43 of Set 10 | lavrentiya
# Processing Record 44 of Set 10 | vila
# Processing Record 45 of Set 10 | soyo
# Processing Record 46 of Set 10 | zhongshu
# Processing Record 47 of Set 10 | bandarbeyla
# Processing Record 48 of Set 10 | tabas
# Processing Record 49 of Set 10 | ninove
# Processing Record 50 of Set 10 | eyrarbakki
# Processing Record 1 of Set 11 | shubarshi
# Processing Record 2 of Set 11 | batagay
# Processing Record 3 of Set 11 | san jeronimo
# Processing Record 4 of Set 11 | manakara
# Processing Record 5 of Set 11 | auki
# Processing Record 6 of Set 11 | nampula
# Processing Record 7 of Set 11 | oga
# Processing Record 8 of Set 11 | ovalle
# Processing Record 9 of Set 11 | broome
# Processing Record 10 of Set 11 | vodnyy
# Processing Record 11 of Set 11 | ilulissat
# Processing Record 12 of Set 11 | katangli
# Processing Record 13 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 11 | maceio
# Processing Record 15 of Set 11 | itirucu
# Processing Record 16 of Set 11 | laguna
# Processing Record 17 of Set 11 | andilamena
# Processing Record 18 of Set 11 | buraydah
# Processing Record 19 of Set 11 | valparaiso
# Processing Record 20 of Set 11 | sao jose da coroa grande
# Processing Record 21 of Set 11 | sabang
# Processing Record 22 of Set 11 | khasan
# Processing Record 23 of Set 11 | charters towers
# Processing Record 24 of Set 11 | rocha
# Processing Record 25 of Set 11 | port-gentil
# Processing Record 26 of Set 11 | sarangani
# Processing Record 27 of Set 11 | mildura
# Processing Record 28 of Set 11 | nyrob
# Processing Record 29 of Set 11 | kahuta
# Processing Record 30 of Set 11 | council bluffs
# Processing Record 31 of Set 11 | oksfjord
# Processing Record 32 of Set 11 | neiafu
# Processing Record 33 of Set 11 | turukhansk
# Processing Record 34 of Set 11 | mareeba
# Processing Record 35 of Set 11 | fredericksburg
# Processing Record 36 of Set 11 | bokony
# Processing Record 37 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 11 | malanje
# Processing Record 39 of Set 11 | ambon
# Processing Record 40 of Set 11 | kerouane
# Processing Record 41 of Set 11 | srednekolymsk
# Processing Record 42 of Set 11 | atagay
# Processing Record 43 of Set 11 | muroto
# Processing Record 44 of Set 11 | ust-nera
# Processing Record 45 of Set 11 | paita
# Processing Record 46 of Set 11 | erzin
# Processing Record 47 of Set 11 | hanko
# Processing Record 48 of Set 11 | huilong
# Processing Record 49 of Set 11 | san rafael
# Processing Record 50 of Set 11 | iracoubo
# Processing Record 1 of Set 12 | parry sound
# Processing Record 2 of Set 12 | mubende
# Processing Record 3 of Set 12 | warri
# Processing Record 4 of Set 12 | luena
# Processing Record 5 of Set 12 | bodden town
# Processing Record 6 of Set 12 | akalgarh
# Processing Record 7 of Set 12 | mangan
# Processing Record 8 of Set 12 | lazaro cardenas
# Processing Record 9 of Set 12 | lata
# Processing Record 10 of Set 12 | tautira
# Processing Record 11 of Set 12 | havelock
# Processing Record 12 of Set 12 | uyuni
# Processing Record 13 of Set 12 | mayor pablo lagerenza
# Processing Record 14 of Set 12 | barra patuca
# Processing Record 15 of Set 12 | coffs harbour
# Processing Record 16 of Set 12 | tarko-sale
# Processing Record 17 of Set 12 | jiayuguan
# Processing Record 18 of Set 12 | moron
# Processing Record 19 of Set 12 | tanjong karang
# City not found. Skipping...
# Processing Record 20 of Set 12 | mehamn
# Processing Record 21 of Set 12 | port lincoln
# Processing Record 22 of Set 12 | nawa
# Processing Record 23 of Set 12 | amapa
# Processing Record 24 of Set 12 | harper
# Processing Record 25 of Set 12 | koslan
# Processing Record 26 of Set 12 | puteyets
# Processing Record 27 of Set 12 | hasaki
# Processing Record 28 of Set 12 | kursavka
# Processing Record 29 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 30 of Set 12 | saint george
# Processing Record 31 of Set 12 | waingapu
# Processing Record 32 of Set 12 | lindi
# Processing Record 33 of Set 12 | tabialan
# City not found. Skipping...
# Processing Record 34 of Set 12 | balabac
# Processing Record 35 of Set 12 | yulara
# Processing Record 36 of Set 12 | romanovo
# Processing Record 37 of Set 12 | shellbrook
# Processing Record 38 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 39 of Set 12 | deputatskiy
# Processing Record 40 of Set 12 | coihaique
# Processing Record 41 of Set 12 | tiznit
# Processing Record 42 of Set 12 | dzhebariki-khaya
# Processing Record 43 of Set 12 | whitecourt
# Processing Record 44 of Set 12 | manjacaze
# Processing Record 45 of Set 12 | opuwo
# Processing Record 46 of Set 12 | axim
# Processing Record 47 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 12 | millville
# Processing Record 49 of Set 12 | yerbogachen
# Processing Record 50 of Set 12 | marfino
# Processing Record 1 of Set 13 | aasiaat
# Processing Record 2 of Set 13 | cabra
# Processing Record 3 of Set 13 | simbahan
# Processing Record 4 of Set 13 | yarkovo
# Processing Record 5 of Set 13 | yarmouth
# Processing Record 6 of Set 13 | hami
# Processing Record 7 of Set 13 | ewa beach
# Processing Record 8 of Set 13 | petropavlovka
# Processing Record 9 of Set 13 | sioux lookout
# Processing Record 10 of Set 13 | garowe
# Processing Record 11 of Set 13 | antofagasta
# Processing Record 12 of Set 13 | cadillac
# Processing Record 13 of Set 13 | mende
# Processing Record 14 of Set 13 | okato
# Processing Record 15 of Set 13 | westerland
# Processing Record 16 of Set 13 | eureka
# Processing Record 17 of Set 13 | bastrop
# Processing Record 18 of Set 13 | yumen
# Processing Record 19 of Set 13 | san jose del palmar
# Processing Record 20 of Set 13 | cootamundra
# Processing Record 21 of Set 13 | karoi
# Processing Record 22 of Set 13 | laje
# Processing Record 23 of Set 13 | olga
# Processing Record 24 of Set 13 | illela
# Processing Record 25 of Set 13 | joao pinheiro
# Processing Record 26 of Set 13 | goya
# Processing Record 27 of Set 13 | am timan
# Processing Record 28 of Set 13 | hirado
# Processing Record 29 of Set 13 | muskegon
# Processing Record 30 of Set 13 | wanaka
# Processing Record 31 of Set 13 | ambulu
# Processing Record 32 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 13 | hirara
# Processing Record 34 of Set 13 | tornio
# Processing Record 35 of Set 13 | zaykovo
# Processing Record 36 of Set 13 | rudbar
# Processing Record 37 of Set 13 | bakaly
# Processing Record 38 of Set 13 | florence
# Processing Record 39 of Set 13 | makakilo city
# Processing Record 40 of Set 13 | nelson bay
# Processing Record 41 of Set 13 | shimanovsk
# Processing Record 42 of Set 13 | dukstas
# Processing Record 43 of Set 13 | xuddur
# Processing Record 44 of Set 13 | yinchuan
# Processing Record 45 of Set 13 | lugazi
# Processing Record 46 of Set 13 | sibolga
# Processing Record 47 of Set 13 | slave lake
# Processing Record 48 of Set 13 | half moon bay
# Processing Record 49 of Set 13 | estelle
# Processing Record 50 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 14 | badin
# Processing Record 2 of Set 14 | lincoln
# Processing Record 3 of Set 14 | viking
# Processing Record 4 of Set 14 | saint-pierre
# Processing Record 5 of Set 14 | kasese
# Processing Record 6 of Set 14 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 7 of Set 14 | mount darwin
# Processing Record 8 of Set 14 | lugovoy
# Processing Record 9 of Set 14 | avera
# Processing Record 10 of Set 14 | zheleznodorozhnyy
# Processing Record 11 of Set 14 | allende
# Processing Record 12 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 14 | port augusta
# Processing Record 15 of Set 14 | mahanoro
# Processing Record 16 of Set 14 | havre-saint-pierre
# Processing Record 17 of Set 14 | tupik
# Processing Record 18 of Set 14 | masterton
# Processing Record 19 of Set 14 | vostok
# Processing Record 20 of Set 14 | hofn
# Processing Record 21 of Set 14 | manihari
# Processing Record 22 of Set 14 | loa janan
# Processing Record 23 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 24 of Set 14 | vesyegonsk
# Processing Record 25 of Set 14 | zabol
# Processing Record 26 of Set 14 | natchez
# Processing Record 27 of Set 14 | amuntai
# Processing Record 28 of Set 14 | santiago del estero
# Processing Record 29 of Set 14 | lagunas
# Processing Record 30 of Set 14 | chik
# Processing Record 31 of Set 14 | manoel urbano
# Processing Record 32 of Set 14 | walvis bay
# Processing Record 33 of Set 14 | sobolevo
# Processing Record 34 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 14 | innisfail
# Processing Record 36 of Set 14 | sisimiut
# Processing Record 37 of Set 14 | lima
# Processing Record 38 of Set 14 | kununurra
# Processing Record 39 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 40 of Set 14 | fukue
# Processing Record 41 of Set 14 | talaya
# Processing Record 42 of Set 14 | glen carbon
# Processing Record 43 of Set 14 | cockburn town
# Processing Record 44 of Set 14 | muzhi
# Processing Record 45 of Set 14 | oparino
# Processing Record 46 of Set 14 | lisakovsk
# Processing Record 47 of Set 14 | neuquen
# Processing Record 48 of Set 14 | navapur
# City not found. Skipping...
# Processing Record 49 of Set 14 | sambava
# Processing Record 50 of Set 14 | lithakia
# Processing Record 1 of Set 15 | treinta y tres
# Processing Record 2 of Set 15 | navahrudak
# Processing Record 3 of Set 15 | qaqortoq
# Processing Record 4 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 5 of Set 15 | peniche
# Processing Record 6 of Set 15 | twin falls
# Processing Record 7 of Set 15 | guicheng
# City not found. Skipping...
# Processing Record 8 of Set 15 | amahai
# Processing Record 9 of Set 15 | black river
# Processing Record 10 of Set 15 | yuanping
# Processing Record 11 of Set 15 | aksu
# Processing Record 12 of Set 15 | tiarei
# Processing Record 13 of Set 15 | kirakira
# Processing Record 14 of Set 15 | ust-ilimsk
# Processing Record 15 of Set 15 | kerrville
# Processing Record 16 of Set 15 | springdale
# Processing Record 17 of Set 15 | pop
# Processing Record 18 of Set 15 | korla
# Processing Record 19 of Set 15 | imbituba
# Processing Record 20 of Set 15 | anloga
# Processing Record 21 of Set 15 | porbandar
# Processing Record 22 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 15 | telimele
# Processing Record 24 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 25 of Set 15 | mount isa
# Processing Record 26 of Set 15 | luganville
# Processing Record 27 of Set 15 | college
# Processing Record 28 of Set 15 | towada
# Processing Record 29 of Set 15 | rudna
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 669

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hosakote      IN  14.2769   77.1699     82.08        43          90
# 1      Katsuura      JP  35.1333  140.3000     73.42        80         100
# 2  Mizan Teferi      ET   6.9833   35.5833     65.01        95          76
# 3         Serik      TR  36.9169   31.0989     75.74        47           2
# 4      Cidreira      BR -30.1811  -50.2056     59.86        97         100
# 5   San Vicente      AR -26.6167  -54.1333     53.55        99          16
# 6       Rikitea      PF -23.1203 -134.9692     73.08        72           3
# 7       Mataura      NZ -46.1927  168.8643     55.47        72          17
# 8      Shaoguan      CN  24.8000  113.5833     96.91        30          23
# 9      Victoria      HK  22.2855  114.1577     91.45        76          37
#
#    Wind Speed Current Description
# 0       15.08     overcast clouds
# 1       19.64     overcast clouds
# 2        1.50          light rain
# 3        3.24           clear sky
# 4        3.02     overcast clouds
# 5        1.50          few clouds
# 6       14.16           clear sky
# 7        3.00          few clouds
# 8        2.04          few clouds
# 9        7.00    scattered clouds

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
